# %% [markdown]
# ### Importing libraries (for text mining)

# %%
from textblob import TextBlob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import nltk
import nltk
import re
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from collections import Counter
sns.set()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/prateeksharma/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/prateeksharma/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/prateeksharma/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ## Tokenization

# %%
myfile = open('Key_events_20th_century.txt', encoding='utf-8')

# %% [markdown]
# # Import txt file

# %%
with open('Key_events_20th_century.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\n', '')

# %% [markdown]
# # Sentence tokenization

# %%
from nltk.tokenize import sent_tokenize
tokenized_sent = sent_tokenize(data)
print(tokenized_sent)
# Out:
# ['Key events of the 20th century - WikipediaJump to contentMain menuMain menumove to sidebarhide\t\tNavigation\tMain pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate\t\tContribute\tHelpLearn to editCommunity portalRecent changesUpload fileSearchSearchCreate accountLog inPersonal tools Create account Log in\t\tPages for logged out editors learn moreContributionsTalkContentsmove to sidebarhide(Top)1Events in the 20th centuryToggle Events in the 20th century subsection1.1The world at the beginning of the century1.1.1"The war to end all wars": World War I (1914–1918)1.1.2The Russian Revolution and Communism1.2Between the wars1.2.1Economic depression1.2.2The rise of dictatorship1.3Global war: World War II (1939–1945)1.3.1The war in Europe1.3.2Blitzkrieg1.3.3Operation Barbarossa1.3.4Turning tides1.3.5Operation Overlord1.3.6Final days1.3.7The war in the Pacific1.3.7.1Background1.3.8Japanese Expansion1.3.9Allied offensive1.3.10Final days1.3.11The Holocaust1.3.12The Nuclear Age begins1.4The post-war world1.4.1The end of empires: decolonization1.4.2The Cold War (1947–1991)1.4.3War by proxy1.4.4The space race1.4.5The end of the Cold War1.4.6Information and communications technology1.5The world at the end of the century2See also3References4Sources5External linksToggle the table of contentsKey events of the 20th century2 languagesالعربيةУкраїнськаEdit linksArticleTalkEnglishReadEditView historyToolsToolsmove to sidebarhide\t\tActions\tReadEditView history\t\tGeneral\tWhat links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite this pageGet shortened URLDownload QR codeWikidata item\t\tPrint/export\tDownload as PDFPrintable version\t\tIn other projects\tWikimedia CommonsFrom Wikipedia, the free encyclopediaThe 20th century changed the world in unprecedented ways.', 'The World Wars sparked tension between countries and led to the creation of atomic bombs, the Cold War led to the Space Race and the creation of space-based rockets, and the World Wide Web was created.', "These advancements have played a significant role in citizens' lives and shaped the 21st century into what it is today.Events in the 20th century[edit]The world at the beginning of the century[edit]Main article: Edwardian eraThe new beginning of the 20th century marked significant changes.", 'The 1900s saw the decade herald a series of inventions, including the automobile, airplane and radio broadcasting.From 1914 to 1918, the First World War, and its aftermath, caused major changes in the power balance of the world, destroying or transforming some of the most powerful empires.', '"The war to end all wars": World War I (1914–1918)[edit]Main article: World War IArrest of a suspect in Sarajevo following the Assassination of Archduke Franz FerdinandThe First World War (or simply WWI), termed "The Great War" by contemporaries, started in 1914 and ended in 1918.', 'The war and by extension the century as a whole was ignited by the Assassination in Sarajevo of the Austro-Hungarian Empire\'s heir to the throne, Erzherzog Franz Ferdinand, by Gavrilo Princip of the organization "Young Bosnia," Bosnian Serbs\' liberation movement.', 'This was similar to how the 9/11 was the inciting incident of the 21st century.', '[1] Bound by Slavic nationalism to help the small Serbian state, the Russians came to the aid of the Serbs when they were attacked.', 'Interwoven alliances, an increasing arms race, and old hatreds dragged Europe into the war.', '[2] The Allies, known initially as "The Triple Entente", comprised the British Empire, France, Italy, and Russia.', 'Germany, Austria-Hungary, Bulgaria, and later the Ottoman Empire, were known as "The Central Powers".', '[3][4]In 1917, Russia ended hostile actions against the Central Powers after the fall of the Tsar.', 'The Bolsheviks negotiated the Treaty of Brest-Litovsk with Germany, although it was a huge cost to Russia.', 'In the treaty, Bolshevik Russia ceded the Baltic states to Germany, and  ...

# %% [markdown]
# # Word tokenization

# %%
from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(data)
print(tokenized_word)
# Out:
# ['Key', 'events', 'of', 'the', '20th', 'century', '-', 'WikipediaJump', 'to', 'contentMain', 'menuMain', 'menumove', 'to', 'sidebarhide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'usDonate', 'Contribute', 'HelpLearn', 'to', 'editCommunity', 'portalRecent', 'changesUpload', 'fileSearchSearchCreate', 'accountLog', 'inPersonal', 'tools', 'Create', 'account', 'Log', 'in', 'Pages', 'for', 'logged', 'out', 'editors', 'learn', 'moreContributionsTalkContentsmove', 'to', 'sidebarhide', '(', 'Top', ')', '1Events', 'in', 'the', '20th', 'centuryToggle', 'Events', 'in', 'the', '20th', 'century', 'subsection1.1The', 'world', 'at', 'the', 'beginning', 'of', 'the', 'century1.1.1', "''", 'The', 'war', 'to', 'end', 'all', 'wars', "''", ':', 'World', 'War', 'I', '(', '1914–1918', ')', '1.1.2The', 'Russian', 'Revolution', 'and', 'Communism1.2Between', 'the', 'wars1.2.1Economic', 'depression1.2.2The', 'rise', 'of', 'dictatorship1.3Global', 'war', ':', 'World', 'War', 'II', '(', '1939–1945', ')', '1.3.1The', 'war', 'in', 'Europe1.3.2Blitzkrieg1.3.3Operation', 'Barbarossa1.3.4Turning', 'tides1.3.5Operation', 'Overlord1.3.6Final', 'days1.3.7The', 'war', 'in', 'the', 'Pacific1.3.7.1Background1.3.8Japanese', 'Expansion1.3.9Allied', 'offensive1.3.10Final', 'days1.3.11The', 'Holocaust1.3.12The', 'Nuclear', 'Age', 'begins1.4The', 'post-war', 'world1.4.1The', 'end', 'of', 'empires', ':', 'decolonization1.4.2The', 'Cold', 'War', '(', '1947–1991', ')', '1.4.3War', 'by', 'proxy1.4.4The', 'space', 'race1.4.5The', 'end', 'of', 'the', 'Cold', 'War1.4.6Information', 'and', 'communications', 'technology1.5The', 'world', 'at', 'the', 'end', 'of', 'the', 'century2See', 'also3References4Sources5External', 'linksToggle', 'the', 'table', 'of', 'contentsKey', 'events', 'of', 'the', '20th', 'century2', 'languagesالعربيةУкраїнськаEdit', 'linksArticleTalkEnglishReadEditView', 'historyToolsToolsmove', 'to', 'sidebarhide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'fileSpecial', 'pagesPermanent', 'linkPage', 'informationCite', 'this', 'pageGet', 'shortened', 'URLDownload', 'QR', 'codeWikidata', 'item', 'Print/export', 'Download', 'as', 'PDFPrintable', 'version', 'In', 'other', 'projects', 'Wikimedia', 'CommonsFrom', 'Wikipedia', ',', 'the', 'free', 'encyclopediaThe', '20th', 'century', 'changed', 'the', 'world', 'in', 'unprecedented', 'ways', '.', 'The', 'World', 'Wars', 'sparked', 'tension', 'between', 'countries', 'and', 'led', 'to', 'the', 'creation', 'of', 'atomic', 'bombs', ',', 'the', 'Cold', 'War', 'led', 'to', 'the', 'Space', 'Race', 'and', 'the', 'creation', 'of', 'space-based', 'rockets', ',', 'and', 'the', 'World', 'Wide', 'Web', 'was', 'created', '.', 'These', 'advancements', 'have', 'played', 'a', 'significant', 'role', 'in', 'citizens', "'", 'lives', 'and', 'shaped', 'the', '21st', 'century', 'into', 'what', 'it', 'is', 'today.Events', 'in', 'the', '20th', 'century', '[', 'edit', ']', 'The', 'world', 'at', 'the', 'beginning', 'of', 'the', 'century', '[', 'edit', ']', 'Main', 'article', ':', 'Edwardian', 'eraThe', 'new', 'beginning', 'of', 'the', '20th', 'century', 'marked', 'significant', 'changes', '.', 'The', '1900s', 'saw', 'the', 'decade', 'herald', 'a', 'series', 'of', 'inventions', ',', 'including', 'the', 'automobile', ',', 'airplane', 'and', 'radio', 'broadcasting.From', '1914', 'to', '1918', ',', 'the', 'First', 'World', 'War', ',', 'and', 'its', 'aftermath', ',', 'caused', 'major', 'changes', 'in', 'the', 'power', 'balance', 'of', 'the', 'world', ',', 'destroying', 'or', 'transforming', 'some', 'of', 'the', 'most', 'powerful', 'empires', '.', '``', 'The', 'war', 'to', 'end', 'all', 'wars', "''", ':', 'World', 'War', 'I', '(', '1914–1918', ')', '[', 'edit', ']', 'Main', 'article', ':', 'World', 'War', 'IArrest', 'of', 'a', 'suspect', 'in', 'Sarajevo', 'following', 'the', 'Assassination', 'of', 'Archduke', 'Franz', 'FerdinandThe', 'First', 'Wo ...

# %%
# Create frequency distribution
from nltk.probability import FreqDist
dist_words = FreqDist(tokenized_word)
print(dist_words)
# Out:
# <FreqDist with 4888 samples and 20364 outcomes>

# %%
dist_words.most_common(10)
# Out:
# [('.', 1285),
#  ('the', 1095),
#  (',', 990),
#  ('of', 604),
#  ('and', 397),
#  ('to', 325),
#  ('[', 303),
#  (']', 303),
#  ('The', 302),
#  ('in', 290)]

# %%
# Frequency Distribution Plot
plt.figure(figsize=(8, 3))
dist_words.plot(10,cumulative = False)
plt.show()

# %% [markdown]
# ## Stopwords

# %%
# Defining stopwords
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {"don't", 'did', 'an', 'nor', "hadn't", "needn't", 'if', "haven't", 'yours', 'doesn', 'their', 'him', 'your', 'below', 'her', "that'll", 'whom', 'ma', 'who', 'down', 'this', "didn't", 'has', 'through', 'you', 'such', "she's", "shouldn't", 'most', 'can', 'or', 'more', 'out', 'up', 'hadn', "mightn't", 'had', 'during', 'again', 'ain', 'until', 'in', 'was', 'does', 'and', 'some', 'themselves', 'o', 'm', "you've", 'its', 'she', 'them', 'aren', 'myself', 'we', 'were', 'with', 'for', 'itself', 'as', "isn't", 'other', 'now', 'so', 'be', 'couldn', "doesn't", 'shan', 'after', "mustn't", 'why', "aren't", 'doing', 'than', 'didn', 'these', 'before', 've', 'they', 'yourselves', 'himself', "wasn't", 'own', 'hasn', 'here', 'too', 'weren', 't', 'under', 'mustn', 'where', 'hers', 'very', 'how', "couldn't", 'when', 'from', 'which', 'ourselves', 'each', 'no', 'all', 'don', 'should', 'his', 'what', 'are', 'been', 'at', "won't", 'yourself', 'both', 'herself', 'haven', 's', 'it', "you'll", 'further', "you'd", 'but', 'because', 'while', 'of', "shan't", 'above', 'same', 'theirs', 'any', 'won', 'between', 'he', 'do', "hasn't", 'that', 'about', 'the', 'll', 'once', 'there', 'our', "wouldn't", 'me', 'is', 'by', 'ours', 'off', 'those', 'to', 'will', 're', "you're", 'a', 'being', 'only', 'over', 'mightn', 'having', 'y', "weren't", 'just', 'i', 'shouldn', 'isn', 'needn', 'am', 'against', 'then', 'my', "it's", 'not', 'have', 'few', 'd', "should've", 'into', 'on', 'wouldn', 'wasn'}

# %%
# Removing stopwords in words
filtered_words = []  # creates an empty list
for word in tokenized_word:
    if word not in stop_words:
        filtered_words.append(word)

# %%
# Create a new FreqDist for filtered_words
dist_words_filter = FreqDist(filtered_words)
print(dist_words_filter)
# Out:
# <FreqDist with 4784 samples and 15703 outcomes>

# %%
# Frequency Distribution Plot
plt.figure(figsize=(8, 3))
dist_words_filter.plot(10, cumulative = False)
plt.show()

# %%
# Substitute all punctuations marks with a space 
sans_punc = re.sub("[^a-zA-Z]",  # Search for all non-letters
                          " ",          # Replace all non-letters with spaces
                          str(filtered_words))

# %%
# Word tokenization
tokenized_word_2 = word_tokenize(sans_punc)
print(tokenized_word_2)
# Out:
# ['Key', 'events', 'th', 'century', 'WikipediaJump', 'contentMain', 'menuMain', 'menumove', 'sidebarhide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'usDonate', 'Contribute', 'HelpLearn', 'editCommunity', 'portalRecent', 'changesUpload', 'fileSearchSearchCreate', 'accountLog', 'inPersonal', 'tools', 'Create', 'account', 'Log', 'Pages', 'logged', 'editors', 'learn', 'moreContributionsTalkContentsmove', 'sidebarhide', 'Top', 'Events', 'th', 'centuryToggle', 'Events', 'th', 'century', 'subsection', 'The', 'world', 'beginning', 'century', 'The', 'war', 'end', 'wars', 'World', 'War', 'I', 'The', 'Russian', 'Revolution', 'Communism', 'Between', 'wars', 'Economic', 'depression', 'The', 'rise', 'dictatorship', 'Global', 'war', 'World', 'War', 'II', 'The', 'war', 'Europe', 'Blitzkrieg', 'Operation', 'Barbarossa', 'Turning', 'tides', 'Operation', 'Overlord', 'Final', 'days', 'The', 'war', 'Pacific', 'Background', 'Japanese', 'Expansion', 'Allied', 'offensive', 'Final', 'days', 'The', 'Holocaust', 'The', 'Nuclear', 'Age', 'begins', 'The', 'post', 'war', 'world', 'The', 'end', 'empires', 'decolonization', 'The', 'Cold', 'War', 'War', 'proxy', 'The', 'space', 'race', 'The', 'end', 'Cold', 'War', 'Information', 'communications', 'technology', 'The', 'world', 'end', 'century', 'See', 'also', 'References', 'Sources', 'External', 'linksToggle', 'table', 'contentsKey', 'events', 'th', 'century', 'languages', 'Edit', 'linksArticleTalkEnglishReadEditView', 'historyToolsToolsmove', 'sidebarhide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'fileSpecial', 'pagesPermanent', 'linkPage', 'informationCite', 'pageGet', 'shortened', 'URLDownload', 'QR', 'codeWikidata', 'item', 'Print', 'export', 'Download', 'PDFPrintable', 'version', 'In', 'projects', 'Wikimedia', 'CommonsFrom', 'Wikipedia', 'free', 'encyclopediaThe', 'th', 'century', 'changed', 'world', 'unprecedented', 'ways', 'The', 'World', 'Wars', 'sparked', 'tension', 'countries', 'led', 'creation', 'atomic', 'bombs', 'Cold', 'War', 'led', 'Space', 'Race', 'creation', 'space', 'based', 'rockets', 'World', 'Wide', 'Web', 'created', 'These', 'advancements', 'played', 'significant', 'role', 'citizens', 'lives', 'shaped', 'st', 'century', 'today', 'Events', 'th', 'century', 'edit', 'The', 'world', 'beginning', 'century', 'edit', 'Main', 'article', 'Edwardian', 'eraThe', 'new', 'beginning', 'th', 'century', 'marked', 'significant', 'changes', 'The', 's', 'saw', 'decade', 'herald', 'series', 'inventions', 'including', 'automobile', 'airplane', 'radio', 'broadcasting', 'From', 'First', 'World', 'War', 'aftermath', 'caused', 'major', 'changes', 'power', 'balance', 'world', 'destroying', 'transforming', 'powerful', 'empires', 'The', 'war', 'end', 'wars', 'World', 'War', 'I', 'edit', 'Main', 'article', 'World', 'War', 'IArrest', 'suspect', 'Sarajevo', 'following', 'Assassination', 'Archduke', 'Franz', 'FerdinandThe', 'First', 'World', 'War', 'simply', 'WWI', 'termed', 'The', 'Great', 'War', 'contemporaries', 'started', 'ended', 'The', 'war', 'extension', 'century', 'whole', 'ignited', 'Assassination', 'Sarajevo', 'Austro', 'Hungarian', 'Empire', 's', 'heir', 'throne', 'Erzherzog', 'Franz', 'Ferdinand', 'Gavrilo', 'Princip', 'organization', 'Young', 'Bosnia', 'Bosnian', 'Serbs', 'liberation', 'movement', 'This', 'similar', 'inciting', 'incident', 'st', 'century', 'Bound', 'Slavic', 'nationalism', 'help', 'small', 'Serbian', 'state', 'Russians', 'came', 'aid', 'Serbs', 'attacked', 'Interwoven', 'alliances', 'increasing', 'arms', 'race', 'old', 'hatreds', 'dragged', 'Europe', 'war', 'The', 'Allies', 'known', 'initially', 'The', 'Triple', 'Entente', 'comprised', 'British', 'Empire', 'France', 'Italy', 'Russia', 'Germany', 'Austria', 'Hungary', 'Bulgaria', 'later', 'Ottoman', 'Empire', 'known', 'The', 'Central', 'Powers', 'In', 'Russia', 'ended', 'hostile', 'actions', 'Central', 'Powers', 'fall', 'Tsar', 'T ...

# %%
# Create a new FreqDist
dist_words_filter_2 = FreqDist(tokenized_word_2)

# %%
# Frequency Distribution Plot
plt.figure(figsize=(8, 3))
dist_words_filter_2.plot(30, cumulative = False)
plt.show()

# %%
dist_words_filter_2.most_common(20)
# Out:
# [('The', 324),
#  ('Retrieved', 205),
#  ('War', 129),
#  ('s', 96),
#  ('war', 91),
#  ('th', 86),
#  ('World', 76),
#  ('Soviet', 61),
#  ('Hitler', 50),
#  ('Germany', 43),
#  ('History', 41),
#  ('world', 39),
#  ('www', 39),
#  ('ISBN', 39),
#  ('In', 38),
#  ('first', 38),
#  ('century', 36),
#  ('Japanese', 36),
#  ('would', 35),
#  ('German', 34)]

# %% [markdown]
# Earlier, the primary elements in the text were mostly punctuation marks. To address this issue, all punctuation marks were replaced with spaces. This adjustment significantly improved the clarity of the text, allowing common words like "The," "Retrieved," and "War" to stand out more prominently. However, some individual letters, such as "s," "th," and "S," also emerged in the list of frequent terms. This occurrence was a result of removing certain punctuation marks during the creation of stopwords.

# %% [markdown]
# ## POS Tags with TextBlob

# %%
new_stopwords = ["And", "Then", 'n', 't', 's', 'The']

# %%
filtered = []
for word in tokenized_word_2:
    if word not in new_stopwords:
        filtered.append(word)

# %%
# %%time
text = TextBlob(str(filtered))
# Out:
# CPU times: user 4.45 ms, sys: 92 µs, total: 4.55 ms
# Wall time: 4.55 ms

# %%
text
# Out:
# TextBlob("['Key', 'events', 'th', 'century', 'WikipediaJump', 'contentMain', 'menuMain', 'menumove', 'sidebarhide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'usDonate', 'Contribute', 'HelpLearn', 'editCommunity', 'portalRecent', 'changesUpload', 'fileSearchSearchCreate', 'accountLog', 'inPersonal', 'tools', 'Create', 'account', 'Log', 'Pages', 'logged', 'editors', 'learn', 'moreContributionsTalkContentsmove', 'sidebarhide', 'Top', 'Events', 'th', 'centuryToggle', 'Events', 'th', 'century', 'subsection', 'world', 'beginning', 'century', 'war', 'end', 'wars', 'World', 'War', 'I', 'Russian', 'Revolution', 'Communism', 'Between', 'wars', 'Economic', 'depression', 'rise', 'dictatorship', 'Global', 'war', 'World', 'War', 'II', 'war', 'Europe', 'Blitzkrieg', 'Operation', 'Barbarossa', 'Turning', 'tides', 'Operation', 'Overlord', 'Final', 'days', 'war', 'Pacific', 'Background', 'Japanese', 'Expansion', 'Allied', 'offensive', 'Final', 'days', 'Holocaust', 'Nuclear', 'Age', 'begins', 'post', 'war', 'world', 'end', 'empires', 'decolonization', 'Cold', 'War', 'War', 'proxy', 'space', 'race', 'end', 'Cold', 'War', 'Information', 'communications', 'technology', 'world', 'end', 'century', 'See', 'also', 'References', 'Sources', 'External', 'linksToggle', 'table', 'contentsKey', 'events', 'th', 'century', 'languages', 'Edit', 'linksArticleTalkEnglishReadEditView', 'historyToolsToolsmove', 'sidebarhide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'fileSpecial', 'pagesPermanent', 'linkPage', 'informationCite', 'pageGet', 'shortened', 'URLDownload', 'QR', 'codeWikidata', 'item', 'Print', 'export', 'Download', 'PDFPrintable', 'version', 'In', 'projects', 'Wikimedia', 'CommonsFrom', 'Wikipedia', 'free', 'encyclopediaThe', 'th', 'century', 'changed', 'world', 'unprecedented', 'ways', 'World', 'Wars', 'sparked', 'tension', 'countries', 'led', 'creation', 'atomic', 'bombs', 'Cold', 'War', 'led', 'Space', 'Race', 'creation', 'space', 'based', 'rockets', 'World', 'Wide', 'Web', 'created', 'These', 'advancements', 'played', 'significant', 'role', 'citizens', 'lives', 'shaped', 'st', 'century', 'today', 'Events', 'th', 'century', 'edit', 'world', 'beginning', 'century', 'edit', 'Main', 'article', 'Edwardian', 'eraThe', 'new', 'beginning', 'th', 'century', 'marked', 'significant', 'changes', 'saw', 'decade', 'herald', 'series', 'inventions', 'including', 'automobile', 'airplane', 'radio', 'broadcasting', 'From', 'First', 'World', 'War', 'aftermath', 'caused', 'major', 'changes', 'power', 'balance', 'world', 'destroying', 'transforming', 'powerful', 'empires', 'war', 'end', 'wars', 'World', 'War', 'I', 'edit', 'Main', 'article', 'World', 'War', 'IArrest', 'suspect', 'Sarajevo', 'following', 'Assassination', 'Archduke', 'Franz', 'FerdinandThe', 'First', 'World', 'War', 'simply', 'WWI', 'termed', 'Great', 'War', 'contemporaries', 'started', 'ended', 'war', 'extension', 'century', 'whole', 'ignited', 'Assassination', 'Sarajevo', 'Austro', 'Hungarian', 'Empire', 'heir', 'throne', 'Erzherzog', 'Franz', 'Ferdinand', 'Gavrilo', 'Princip', 'organization', 'Young', 'Bosnia', 'Bosnian', 'Serbs', 'liberation', 'movement', 'This', 'similar', 'inciting', 'incident', 'st', 'century', 'Bound', 'Slavic', 'nationalism', 'help', 'small', 'Serbian', 'state', 'Russians', 'came', 'aid', 'Serbs', 'attacked', 'Interwoven', 'alliances', 'increasing', 'arms', 'race', 'old', 'hatreds', 'dragged', 'Europe', 'war', 'Allies', 'known', 'initially', 'Triple', 'Entente', 'comprised', 'British', 'Empire', 'France', 'Italy', 'Russia', 'Germany', 'Austria', 'Hungary', 'Bulgaria', 'later', 'Ottoman', 'Empire', 'known', 'Central', 'Powers', 'In', 'Russia', 'ended', 'hostile', 'actions', 'Central', 'Powers', 'fall', 'Tsar', 'Bolsheviks', 'negotiated', 'Treaty', 'Brest', 'Litovsk', 'Germany', 'although', 'huge', 'cost', 'Russia', 'In', 'treaty', 'Bolshevik', 'Russia', 'ceded', 'Baltic' ...

# %%
tags_list = text.tags
tags_list
# Out:
# [('[', 'JJ'),
#  ("'Key", 'NNP'),
#  ("'", 'POS'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'WikipediaJump", 'NNP'),
#  ("'", 'POS'),
#  ("'menumove", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebarhide", 'NNP'),
#  ("'", 'POS'),
#  ("'Navigation", 'NN'),
#  ("'pageContentsCurrent", 'NNP'),
#  ("'", 'POS'),
#  ("'eventsRandom", 'NNP'),
#  ("'", 'POS'),
#  ("'articleAbout", 'IN'),
#  ("'WikipediaContact", 'NNP'),
#  ("'", 'POS'),
#  ("'usDonate", 'NNP'),
#  ("'", 'POS'),
#  ("'HelpLearn", 'NNP'),
#  ("'", 'POS'),
#  ("'editCommunity", 'NNP'),
#  ("'", 'POS'),
#  ("'portalRecent", 'NNP'),
#  ("'", 'POS'),
#  ("'fileSearchSearchCreate", 'NNP'),
#  ("'", 'POS'),
#  ("'accountLog", 'NNP'),
#  ("'", 'POS'),
#  ("'inPersonal", 'NNP'),
#  ("'", 'POS'),
#  ("'tools", 'NNS'),
#  ("'", 'POS'),
#  ("'Create", 'NNP'),
#  ("'", 'POS'),
#  ("'account", 'NNP'),
#  ("'", 'POS'),
#  ("'Log", 'NNP'),
#  ("'", 'POS'),
#  ("'Pages", 'NNS'),
#  ("'", 'POS'),
#  ("'logged", 'VBD'),
#  ("'editors", 'NNS'),
#  ("'", 'POS'),
#  ("'learn", 'NNP'),
#  ("'", 'POS'),
#  ("'moreContributionsTalkContentsmove", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebarhide", 'NNP'),
#  ("'", 'POS'),
#  ("'Events", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'centuryToggle", 'NNP'),
#  ("'", 'POS'),
#  ("'Events", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'subsection", 'NN'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'beginning", 'VBG'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'Russian", 'JJ'),
#  ("'Revolution", 'NNP'),
#  ("'", 'POS'),
#  ("'Communism", 'NN'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'Economic", 'NNP'),
#  ("'", 'POS'),
#  ("'depression", 'NN'),
#  ("'rise", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'II", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'Blitzkrieg", 'NNP'),
#  ("'", 'POS'),
#  ("'Operation", 'NN'),
#  ("'Turning", 'VBG'),
#  ("'tides", 'NNS'),
#  ("'", 'POS'),
#  ("'Operation", 'NN'),
#  ("'Overlord", 'NNP'),
#  ("'", 'POS'),
#  ("'Final", 'NNP'),
#  ("'", 'POS'),
#  ("'days", 'NNS'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'Pacific", 'NNP'),
#  ("'", 'POS'),
#  ("'Background", 'IN'),
#  ("'Japanese", 'JJ'),
#  ("'Expansion", 'NNP'),
#  ("'", 'POS'),
#  ("'Allied", 'VBD'),
#  ("'offensive", 'CD'),
#  ("'Final", 'NNP'),
#  ("'", 'POS'),
#  ("'days", 'NNS'),
#  ("'", 'POS'),
#  ("'Holocaust", 'NNP'),
#  ("'", 'POS'),
#  ("'Age", 'NNP'),
#  ("'", 'POS'),
#  ("'begins", 'NNS'),
#  ("'", 'POS'),
#  ("'post", 'FW'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'empires", 'NNS'),
#  ("'", 'POS'),
#  ("'decolonization", 'NN'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'proxy", 'NNP'),
#  ("'", 'POS'),
#  ("'space", 'NNP'),
#  ("'", 'POS'),
#  ("'race", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'Information", 'NN'),
#  ("'communications", 'NNS'),
#  ("'", 'POS'),
#  ("'technology", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'References", 'NNS'),
#  ("'", 'POS'),
#  ("'Sources", 'NNS'),
#  ("'", 'POS'),
#  ("'External", 'NNP'),
#  ("'", 'POS'),
#  ("'linksToggle", 'NNP'),
#  ("'", 'POS'),
#  ("'table", 'JJ'),
#  ("'contentsKey", 'NNP'),
#  ("'", 'POS'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'languages", 'NNS'),
#  ("'", 'POS'),
#  ("'Edit", 'NNP'),
#  ("'", 'POS'),
#  ("'linksArticleTalkEnglishReadEditView", 'NNP'),
#  ("'", 'POS'),
#  ("'historyToolsToolsmove", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebarhide", 'NNP'),
#  ("'", 'POS'),
#  ("'Actions", 'NNS'),
#  ("'", 'POS'),
#  ("'ReadEditView", 'NNP'),
#  ("'", 'POS'),
#  ("'history", 'NNP'),
#  ("'", 'POS'),
#  ("'General", 'NNP'),
#  ("'", 'POS'),
#  ("'What", 'WP'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'hereRelated", 'VBD'),
#  ("'fileSpecial", 'NNP'),
#  ("'", 'POS'),
#  ("'pagesPermanent", 'NNP'),
#  ("'", 'POS'),
#  ("'linkPage", 'NN'),
#  ("'informationCite", 'NNP'),
#  ("'", 'POS'),
#  ("'shortened", 'VBD'),
#  ("'QR", 'NNP'),
#  ("'", 'POS'),
#  ("'codeWikidata", 'NNP'),
#  ("'", 'POS'),
#  ("'item", 'NNP'),
#  ("'", 'POS'),
#  ("'Print", 'NNP'),
#  ("'", 'POS'),
#  ("'export", 'NNP'),
#  ("'", 'POS'),
#  ("'PDFPrintable", 'JJ'),
#  ("'version", 'NNP'),
#  ("'", 'POS'),
#  ("'In", 'NNP'),
#  ("'", 'POS'),
#  ("'projects", 'NNS'),
#  ("'", 'POS'),
#  ("'Wikimedia", 'NNP'),
#  ("'", 'POS'),
#  ("'CommonsFrom", 'IN'),
#  ("'Wikipedia", 'NNP'),
#  ("'", 'POS'),
#  ("'encyclopediaThe", 'NNP'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'changed", 'VBD'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'unprecedented", 'VBD'),
#  ("'ways", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'Wars", 'NNS'),
#  ("'", 'POS'),
#  ("'sparked", 'VBD'),
#  ("'tension", 'NNP'),
#  ("'", 'POS'),
#  ("'countries", 'NNS'),
#  ("'", 'POS'),
#  ("'led", 'VBD'),
#  ("'creation", 'NNP'),
#  ("'", 'POS'),
#  ("'atomic", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'led", 'VBD'),
#  ("'Space", 'NNP'),
#  ("'", 'POS'),
#  ("'Race", 'NNP'),
#  ("'", 'POS'),
#  ("'creation", 'NN'),
#  ("'space", 'NNP'),
#  ("'", 'POS'),
#  ("'based", 'VBD'),
#  ("'rockets", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'Wide", 'NNP'),
#  ("'", 'POS'),
#  ("'Web", 'NNP'),
#  ("'", 'POS'),
#  ("'created", 'VBD'),
#  ("'These", 'JJ'),
#  ("'advancements", 'NNS'),
#  ("'", 'POS'),
#  ("'significant", 'NNP'),
#  ("'", 'POS'),
#  ("'role", 'NNP'),
#  ("'", 'POS'),
#  ("'citizens", 'NNS'),
#  ("'", 'POS'),
#  ("'lives", 'NNS'),
#  ("'", 'POS'),
#  ("'shaped", 'VBD'),
#  ("'st", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'Events", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'beginning", 'VBG'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'Edwardian", 'JJ'),
#  ("'eraThe", 'NNP'),
#  ("'", 'POS'),
#  ("'new", 'NNP'),
#  ("'", 'POS'),
#  ("'beginning", 'VBG'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'marked", 'VBD'),
#  ("'significant", 'NNP'),
#  ("'", 'POS'),
#  ("'changes", 'NNS'),
#  ("'", 'POS'),
#  ("'saw", 'NNP'),
#  ("'", 'POS'),
#  ("'herald", 'NNP'),
#  ("'", 'POS'),
#  ("'series", 'NNS'),
#  ("'", 'POS'),
#  ("'inventions", 'NNS'),
#  ("'", 'POS'),
#  ("'including", 'VBG'),
#  ("'automobile", 'IN'),
#  ("'airplane", 'NNP'),
#  ("'", 'POS'),
#  ("'radio", 'NNP'),
#  ("'", 'POS'),
#  ("'broadcasting", 'VBG'),
#  ("'From", 'IN'),
#  ("'First", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'aftermath", 'NNP'),
#  ("'", 'POS'),
#  ("'caused", 'VBD'),
#  ("'changes", 'NNS'),
#  ("'", 'POS'),
#  ("'power", 'NNP'),
#  ("'", 'POS'),
#  ("'balance", 'NN'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'destroying", 'VBG'),
#  ("'transforming", 'VBG'),
#  ("'empires", 'NNS'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'IArrest", 'JJS'),
#  ("'suspect", 'NNP'),
#  ("'", 'POS'),
#  ("'Sarajevo", 'NNP'),
#  ("'", 'POS'),
#  ("'following", 'VBG'),
#  ("'Assassination", 'NNP'),
#  ("'", 'POS'),
#  ("'Archduke", 'NNP'),
#  ("'", 'POS'),
#  ("'Franz", 'NNP'),
#  ("'", 'POS'),
#  ("'FerdinandThe", 'NNP'),
#  ("'", 'POS'),
#  ("'First", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'simply", 'NNP'),
#  ("'", 'POS'),
#  ("'WWI", 'NNP'),
#  ("'", 'POS'),
#  ("'termed", 'VBD'),
#  ("'Great", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'contemporaries", 'NNS'),
#  ("'", 'POS'),
#  ("'started", 'VBD'),
#  ("'ended", 'VBD'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'extension", 'NN'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'whole", 'NNP'),
#  ("'", 'POS'),
#  ("'ignited", 'VBD'),
#  ("'Assassination", 'NNP'),
#  ("'", 'POS'),
#  ("'Sarajevo", 'NNP'),
#  ("'", 'POS'),
#  ("'Austro", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungarian", 'JJ'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'throne", 'CD'),
#  ("'Erzherzog", 'NNP'),
#  ("'", 'POS'),
#  ("'Franz", 'NNP'),
#  ("'", 'POS'),
#  ("'Ferdinand", 'NNP'),
#  ("'", 'POS'),
#  ("'Gavrilo", 'NNP'),
#  ("'", 'POS'),
#  ("'Princip", 'NNP'),
#  ("'", 'POS'),
#  ("'organization", 'NN'),
#  ("'Young", 'NNP'),
#  ("'", 'POS'),
#  ("'Bosnia", 'NNP'),
#  ("'", 'POS'),
#  ("'Bosnian", 'JJ'),
#  ("'Serbs", 'NNP'),
#  ("'", 'POS'),
#  ("'liberation", 'NN'),
#  ("'movement", 'NNP'),
#  ("'", 'POS'),
#  ("'This", 'NNP'),
#  ("'", 'POS'),
#  ("'inciting", 'VBG'),
#  ("'incident", 'NNP'),
#  ("'", 'POS'),
#  ("'st", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'Bound", 'IN'),
#  ("'Slavic", 'NNP'),
#  ("'", 'POS'),
#  ("'nationalism", 'NN'),
#  ("'small", 'DT'),
#  ("'Serbian", 'JJ'),
#  ("'state", 'NNP'),
#  ("'", 'POS'),
#  ("'Russians", 'NNS'),
#  ("'", 'POS'),
#  ("'aid", 'NNP'),
#  ("'", 'POS'),
#  ("'Serbs", 'NNP'),
#  ("'", 'POS'),
#  ("'attacked", 'VBD'),
#  ("'alliances", 'NNS'),
#  ("'", 'POS'),
#  ("'increasing", 'VBG'),
#  ("'arms", 'NNS'),
#  ("'", 'POS'),
#  ("'race", 'NNP'),
#  ("'", 'POS'),
#  ("'hatreds", 'NNS'),
#  ("'", 'POS'),
#  ("'dragged", 'VBD'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'Allies", 'NNS'),
#  ("'", 'POS'),
#  ("'initially", 'RB'),
#  ("'", 'POS'),
#  ("'Entente", 'NNP'),
#  ("'", 'POS'),
#  ("'comprised", 'VBD'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'France", 'NN'),
#  ("'Italy", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'Austria", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungary", 'NNP'),
#  ("'", 'POS'),
#  ("'Bulgaria", 'NNP'),
#  ("'", 'POS'),
#  ("'later", 'NNP'),
#  ("'", 'POS'),
#  ("'Ottoman", 'NNP'),
#  ("'", 'POS'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'Central", 'NNP'),
#  ("'", 'POS'),
#  ("'Powers", 'NNS'),
#  ("'", 'POS'),
#  ("'In", 'NNP'),
#  ("'", 'POS'),
#  ("'ended", 'VBD'),
#  ("'hostile", 'IN'),
#  ("'actions", 'NNS'),
#  ("'", 'POS'),
#  ("'Central", 'NNP'),
#  ("'", 'POS'),
#  ("'Powers", 'NNS'),
#  ("'", 'POS'),
#  ("'Tsar", 'NNP'),
#  ("'", 'POS'),
#  ("'Bolsheviks", 'NNP'),
#  ("'", 'POS'),
#  ("'negotiated", 'VBD'),
#  ("'Treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'Brest", 'JJS'),
#  ("'Litovsk", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'although", 'IN'),
#  ("'cost", 'FW'),
#  ("'", 'POS'),
#  ("'In", 'NNP'),
#  ("'", 'POS'),
#  ("'treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'Bolshevik", 'NNP'),
#  ("'", 'POS'),
#  ("'ceded", 'VBD'),
#  ("'Baltic", 'JJ'),
#  ("'states", 'VBZ'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'province", 'NN'),
#  ("'Kars", 'NNS'),
#  ("'", 'POS'),
#  ("'South", 'NNP'),
#  ("'", 'POS'),
#  ("'Caucasus", 'NNP'),
#  ("'", 'POS'),
#  ("'Ottoman", 'NNP'),
#  ("'", 'POS'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'It", 'NNP'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'recognized", 'VBN'),
#  ("'independence", 'NNP'),
#  ("'", 'POS'),
#  ("'Ukraine", 'NNP'),
#  ("'", 'POS'),
#  ("'Although", 'IN'),
#  ("'", 'POS'),
#  ("'shifted", 'VBD'),
#  ("'forces", 'NNS'),
#  ("'", 'POS'),
#  ("'eastern", 'NNP'),
#  ("'", 'POS'),
#  ("'western", 'NNP'),
#  ("'", 'POS'),
#  ("'front", 'NNP'),
#  ("'", 'POS'),
#  ("'signing", 'VBG'),
#  ("'treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'unable", 'JJ'),
#  ("'stop", 'NNP'),
#  ("'", 'POS'),
#  ("'Allied", 'VBD'),
#  ("'advance", 'NNP'),
#  ("'", 'POS'),
#  ("'especially", 'RB'),
#  ("'", 'POS'),
#  ("'entrance", 'NN'),
#  ("'American", 'JJ'),
#  ("'troops", 'NNS'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'chance", 'NN'),
#  ("'combatant", 'NNP'),
#  ("'", 'POS'),
#  ("'nations", 'NNS'),
#  ("'", 'POS'),
#  ("'show", 'NNP'),
#  ("'", 'POS'),
#  ("'military", 'NNP'),
#  ("'", 'POS'),
#  ("'strength", 'NNP'),
#  ("'", 'POS'),
#  ("'technological", 'JJ'),
#  ("'ingenuity", 'NNP'),
#  ("'", 'POS'),
#  ("'Germans", 'NNS'),
#  ("'", 'POS'),
#  ("'introduced", 'VBD'),
#  ("'machine", 'NNP'),
#  ("'", 'POS'),
#  ("'gun", 'NNP'),
#  ("'", 'POS'),
#  ('U', 'NNP'),
#  ("'", 'POS'),
#  ("'boats", 'NNS'),
#  ("'", 'POS'),
#  ("'deadly", 'RB'),
#  ("'gases", 'NNS'),
#  ("'", 'POS'),
#  ("'first", 'NNP'),
#  ("'", 'POS'),
#  ("'used", 'VBD'),
#  ("'tank", 'NNP'),
#  ("'", 'POS'),
#  ("'Both", 'NNP'),
#  ("'", 'POS'),
#  ("'sides", 'NNS'),
#  ("'", 'POS'),
#  ("'chance", 'NN'),
#  ("'test", 'JJS'),
#  ("'new", 'NNP'),
#  ("'", 'POS'),
#  ("'aircraft", 'NNP'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'could", 'MD'),
#  ("'used", 'VBD'),
#  ("'warfare", 'NNP'),
#  ("'", 'POS'),
#  ("'It", 'NNP'),
#  ("'", 'POS'),
#  ("'widely", 'RB'),
#  ("'believed", 'VBD'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'would", 'MD'),
#  ("'short", 'NNP'),
#  ("'", 'POS'),
#  ("'Unfortunately", 'RB'),
#  ("'since", 'NNP'),
#  ("'", 'POS'),
#  ("'warfare", 'NNP'),
#  ("'", 'POS'),
#  ("'best", 'JJS'),
#  ("'advances", 'NNS'),
#  ("'", 'POS'),
#  ("'sides", 'NNS'),
#  ("'", 'POS'),
#  ("'slow", 'NNP'),
#  ("'", 'POS'),
#  ("'terrible", 'JJ'),
#  ("'cost", 'FW'),
#  ("'", 'POS'),
#  ("'lives", 'NNS'),
#  ("'", 'POS'),
#  ("'Division", 'NN'),
#  ("'Austria", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungary", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'IWhen", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'finally", 'RB'),
#  ("'", 'POS'),
#  ("'results", 'NNS'),
#  ("'", 'POS'),
#  ("'would", 'MD'),
#  ("'set", 'NNP'),
#  ("'", 'POS'),
#  ("'stage", 'NN'),
#  ("'twenty", 'NNP'),
#  ("'", 'POS'),
#  ("'years", 'NNS'),
#  ("'", 'POS'),
#  ("'First", 'NNP'),
#  ("'", 'POS'),
#  ("'foremost", 'FW'),
#  ("'", 'POS'),
#  ("'Germans", 'NNS'),
#  ("'", 'POS'),
#  ("'forced", 'VBD'),
#  ("'sign", 'NNP'),
#  ("'", 'POS'),
#  ("'Treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'Versailles", 'NNS'),
#  ("'", 'POS'),
#  ("'forcing", 'VBG'),
#  ("'make", 'NNP'),
#  ("'", 'POS'),
#  ("'exorbitant", 'NNP'),
#  ("'", 'POS'),
#  ("'payments", 'NNS'),
#  ("'", 'POS'),
#  ("'repair", 'NNP'),
#  ("'", 'POS'),
#  ("'damages", 'NNS'),
#  ("'", 'POS'),
#  ("'caused", 'VBD'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'Germans", 'NNS'),
#  ("'", 'POS'),
#  ("'felt", 'NNP'),
#  ("'", 'POS'),
#  ("'reparations", 'NNS'),
#  ("'", 'POS'),
#  ("'unfair", 'NNP'),
#  ("'", 'POS'),
#  ("'actually", 'RB'),
#  ("'", 'POS'),
#  ("'lose", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'feel", 'NNP'),
#  ("'", 'POS'),
#  ("'caused", 'VBD'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'in", 'NNP'),
#  ("'", 'POS'),
#  ("'the", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'occupied", 'VBD'),
#  ("'Allied", 'VBD'),
#  ("'troops", 'NNS'),
#  ("'", 'POS'),
#  ("'yet", 'NNP'),
#  ("'", 'POS'),
#  ("'accept", 'IN'),
#  ("'liberal", 'NNP'),
#  ("'", 'POS'),
#  ("'democratic", 'JJ'),
#  ("'government", 'NNP'),
#  ("'", 'POS'),
#  ("'imposed", 'VBD'),
#  ("'victors", 'NNS'),
#  ("'", 'POS'),
#  ("'abdication", 'NN'),
#  ("'Kaiser", 'NNP'),
#  ("'", 'POS'),
#  ("'Wilhelm", 'NNP'),
#  ("'", 'POS'),
#  ("'Much", 'JJ'),
#  ("'map", 'NNP'),
#  ("'", 'POS'),
#  ("'redrawn", 'NNP'),
#  ("'", 'POS'),
#  ("'victors", 'NNS'),
#  ("'", 'POS'),
#  ("'based", 'VBD'),
#  ("'theory", 'NNP'),
#  ("'", 'POS'),
#  ("'future", 'NN'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'could", 'MD'),
#  ("'prevented", 'VBD'),
#  ("'ethnic", 'NNP'),
#  ("'", 'POS'),
#  ("'groups", 'NNS'),
#  ("'", 'POS'),
#  ("'homeland", 'NNP'),
#  ("'", 'POS'),
#  ("'New", 'NNP'),
#  ("'", 'POS'),
#  ("'states", 'NNS'),
#  ("'", 'POS'),
#  ("'like", 'IN'),
#  ("'Yugoslavia", 'NNP'),
#  ("'", 'POS'),
#  ("'Czechoslovakia", 'NNP'),
#  ("'", 'POS'),
#  ("'created", 'VBD'),
#  ("'Austro", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungarian", 'JJ'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'accommodate", 'NNP'),
#  ("'", 'POS'),
#  ("'aspirations", 'NNS'),
#  ("'", 'POS'),
#  ("'groups", 'NNS'),
#  ("'", 'POS'),
#  ("'An", 'NNP'),
#  ("'", 'POS'),
#  ("'international", 'NNP'),
#  ("'", 'POS'),
#  ("'body", 'NN'),
#  ("'called", 'VBD'),
#  ("'League", 'NNP'),
#  ("'", 'POS'),
#  ("'Nations", 'NNS'),
#  ("'", 'POS'),
#  ("'formed", 'VBD'),
#  ("'mediate", 'NNP'),
#  ("'", 'POS'),
#  ("'disputes", 'NNS'),
#  ("'", 'POS'),
#  ("'prevent", 'NNP'),
#  ("'", 'POS'),
#  ("'future", 'NN'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'although", 'IN'),
#  ("'effectiveness", 'NNP'),
#  ("'", 'POS'),
#  ("'severely", 'RB'),
#  ("'limited", 'VBD'),
#  ("'among", 'NNP'),
#  ("'", 'POS'),
#  ("'things", 'NNS'),
#  ("'", 'POS'),
#  ("'reluctance", 'NN'),
#  ("'inability", 'NNP'),
#  ("'", 'POS'),
#  ("'act", 'NNP'),
#  ("'", 'POS'),
#  ("'Russian", 'JJ'),
#  ("'Revolution", 'NNP'),
#  ("'", 'POS'),
#  ("'Communism", 'NN'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'Russian", 'JJ'),
#  ("'RevolutionThe", 'NNP'),
#  ("'", 'POS'),
#  ("'Russian", 'JJ'),
#  ("'Revolution", 'NNP'),
#  ("'", 'POS'),
#  ("'ending", 'VBG'),
#  ("'regime", 'NNP'),
#  ("'", 'POS'),
#  ("'execution", 'NN'),
#  ("'His", 'NNP'),
#  ("'", 'POS'),
#  ("'Imperial", 'NNP'),
#  ("'", 'POS'),
#  ("'Majesty", 'NNP'),
#  ("'", 'POS'),
#  ("'Nicholas", 'NNS'),
#  ("'", 'POS'),
#  ("'II", 'NNP'),
#  ("'", 'POS'),
#  ("'family", 'RB'),
#  ("'", 'POS'),
#  ("'sparked", 'VBD'),
#  ("'wave", 'NNP'),
#  ("'", 'POS'),
#  ("'revolutions", 'NNS'),
#  ("'", 'POS'),
#  ("'across", 'IN'),
#  ("'prompting", 'VBG'),
#  ("'", 'POS'),
#  ("'believe", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'revolution", 'NN'),
#  ("'could", 'MD'),
#  ("'realized", 'VBN'),
#  ("'near", 'IN'),
#  ("'future", 'NN'),
#  ("'revolutions", 'NNS'),
#  ("'", 'POS'),
#  ("'defeated", 'VBD'),
#  ("'Vladimir", 'NNP'),
#  ("'", 'POS'),
#  ("'Lenin", 'NNP'),
#  ("'", 'POS'),
#  ("'died", 'VBD'),
#  ("'within", 'NNP'),
#  ("'", 'POS'),
#  ("'years", 'NNS'),
#  ("'", 'POS'),
#  ("'Joseph", 'NNP'),
#  ("'", 'POS'),
#  ("'Stalin", 'NNP'),
#  ("'", 'POS'),
#  ("'displaced", 'VBD'),
#  ("'Leon", 'NNP'),
#  ("'", 'POS'),
#  ("'Trotsky", 'NNP'),
#  ("'", 'POS'),
#  ("'de", 'NNP'),
#  ("'", 'POS'),
#  ("'facto", 'NNP'),
#  ("'", 'POS'),
#  ("'Soviet", 'NNP'),
#  ("'", 'POS'),
#  ("'Union", 'NN'),
#  ("'idea", 'NNP'),
#  ("'", 'POS'),
#  ("'worldwide", 'NNP'),
#  ("'", 'POS'),
#  ("'revolution", 'NN'),
#  ("'longer", 'NNP'),
#  ("'", 'POS'),
#  ("'forefront", 'NNP'),
#  ("'", 'POS'),
#  ("'Stalin", 'NNP'),
#  ("'", 'POS'),
#  ("'concentrated", 'VBD'),
#  ("'socialism", 'NNP'),
#  ("'", 'POS'),
#  ("'one", 'CD'),
#  ("'country", 'NNP'),
#  ("'", 'POS'),
#  ("'embarked", 'VBD'),
#  ("'plan", 'NNP'),
#  ("'", 'POS'),
#  ("'collectivization", 'NN'),
#  ("'industrialization", 'NNP'),
#  ("'", 'POS'),
#  ("'majority", 'NNP'),
#  ("'", 'POS'),
#  ("'socialists", 'NNS'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'communists", 'NNS'),
#  ("'", 'POS'),
#  ("'disillusioned", 'VBD'),
#  ("'Stalin", 'NNP'),
#  ("'", 'POS'),
#  ("'autocratic", 'JJ'),
#  ("'rule", 'NNP'),
#  ("'", 'POS'),
#  ("'purges", 'NNS'),
#  ("'", 'POS'),
#  ("'assassination", 'NN'),
#  ("'enemies", 'NNS'),
#  ("'", 'POS'),
#  ("'well", 'NNP'),
#  ("'", 'POS'),
#  ("'news", 'NNS'),
#  ("'", 'POS'),
#  ("'famines", 'NNS'),
#  ("'", 'POS'),
#  ("'imposed", 'VBD'),
#  ("'Communism", 'NNP'),
#  ("'", 'POS'),
#  ("'strengthened", 'VBD'),
#  ("'force", 'NNP'),
#  ("'", 'POS'),
#  ("'Western", 'NNP'),
#  ("'", 'POS'),
#  ("'democracies", 'NNS'),
#  ("'", 'POS'),
#  ("'economy", 'NNP'),
#  ("'", 'POS'),
#  ("'crashed", 'VBD'),
#  ("'Great", 'NNP'),
#  ("'", 'POS'),
#  ("'Depression", 'NN'),
#  ("'", 'POS'),
#  ("'saw", 'NNP'),
#  ("'", 'POS'),
#  ("'first", 'NNP'),
#  ("'", 'POS'),
#  ...]

# %%
df_text = pd.DataFrame(tags_list)
df_text.columns = [ 'Words', "Word type"]
df_t=df_text.groupby('Word type').count().reset_index()
top10=df_t.nlargest(10, 'Words')

# %%
plt.figure(figsize = (10, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x = "Words", y = "Word type",
    saturation = 0.9, data = top10).set_title("Key events of 20th century - top 10 word types used")

# %% [markdown]
# #### Nouns

# %%
df = df_text[(df_text['Word type'] == "NN") | (df_text['Word type'] == "NNS") | (df_text['Word type'] == "NNP")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top15 = y.nlargest(15, 'Occurences')

# %%
plt.figure(figsize=(12, 6))
with sns.dark_palette("xkcd:blue", 15):
    sns.barplot(x="Word", y="Occurences",
    saturation=0.9, data=top15).set_title("Key events of 20th century - most frequently used nouns")
    plt.xticks(rotation=45)  
    plt.tight_layout()

# %% [markdown]
# #### Verbs

# %%
df = df_text[(df_text['Word type'] == "VB")  | (df_text['Word type'] == "VBD")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top15 = y.nlargest(10, 'Occurences')

# %%
plt.figure(figsize=(12, 6))
with sns.dark_palette("xkcd:blue", 15):
    sns.barplot(x="Word", y="Occurences",
    saturation=0.9, data=top15).set_title("Key events of 20th century - most frequently used verbs")
    plt.xticks(rotation=45)  
    plt.tight_layout()

# %% [markdown]
# #### Adjectives

# %%
df = df_text[df_text['Word type'] == "JJ"]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by=['Occurences'], ascending=False)
top15 = y.nlargest(15, 'Occurences')

# %%
plt.figure(figsize=(12, 6))
with sns.dark_palette("xkcd:blue", 15):
    sns.barplot(x="Word", y="Occurences",
    saturation=0.9, data=top15).set_title("Key events of 20th century - most frequently used adjectives")
    plt.xticks(rotation=45)  
    plt.tight_layout()

# %% [markdown]
# Among nouns, 'War' emerged as the most frequently occurring term, while 'Retrieved' stood out as the dominant verb. Additionally, 'Japanese' held the highest frequency as an adjective, shedding light on prevalent discussion patterns concerning the 20th century."

# %%
# Load the list of countries from the CSV file and clean the names
countries_df = pd.read_csv("countries_list.csv")
countries_df['country_name'] = countries_df['country_name'].str.strip()
countries_list = countries_df['country_name'].tolist()

# %%
# Load the text data
with open('Key_events_20th_century.txt', 'r', encoding='utf-8', errors='ignore') as file:
    data = file.read().replace('\n', ' ')

# %%
# Convert the text to lowercase for consistent matching
data_lower = data.lower()

# %%
# Initialize a Counter to count occurrences of each country name
country_counts = Counter()

# %%
# Count occurrences of each country in the text
for country in countries_list:
    count = data_lower.count(country.lower())
    country_counts[country] = count

# %%
# Convert the Counter to a DataFrame
country_counts_df = pd.DataFrame(country_counts.items(), columns=['Country', 'Mentions'])

# %%
# Sort the DataFrame by the number of mentions in descending order
country_counts_df = country_counts_df.sort_values(by='Mentions', ascending=False)

# %%
# Display the DataFrame
country_counts_df
# Out:
#            Country  Mentions
# 85           Japan        69
# 64         Germany        43
# 185  United States        23
# 144         Russia        19
# 191        Vietnam        16
# ..             ...       ...
# 84         Jamaica         0
# 86          Jordan         0
# 87      Kazakhstan         0
# 89        Kiribati         0
# 207   Transnistria         0
#
# [208 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Mentions', y='Country', data=country_counts_df)
plt.title('Frequency of Country Mentions')
plt.xlabel('Number of Mentions')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# The output is very cluttered and difficult to interpret. To solve this issue i will filter the country name frequence to more than or equal to 3.

# %%
# Filter out country mentions with frequency greater than or equal to 3
filtered_country_counts_df = country_counts_df[country_counts_df['Mentions'] >= 3]

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Mentions', y='Country', data=filtered_country_counts_df)
plt.title('Frequency of Country Mentions (Frequency >=3)')
plt.xlabel('Number of Mentions')
plt.ylabel('Country')
plt.show()
